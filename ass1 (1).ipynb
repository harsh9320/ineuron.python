# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
#  *
#
# 'hello'
#
#
#
# -
#
# /
#
# +
#
# 6
#
# Ans : values:  'hello',-87.8 , 6
#       mathematical operators :  * , - , / , +
#
#
# 2. What is the difference between string and variable?
# Ans: string is type of data or information and variable is used to store any data or information in a particular memory location.
#
#
# 3. Describe three different data types.
# Ans: string(str), integer(int) , float(float)
#
#
#
# 4. What is an expression made up of? What do all expressions do?
# Ans: Expressions are made of combinations of variables,characters, and operators.
#      Python interprete the expressions  to evlauate and displays results.
#
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans: Statement is a instruction or set of instructions that are interpreted and executed by python to give output.
#
#
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
#
# Ans : 23
#
#
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam' = 'spamspamspam'
#
# 'spam' * 3 =  'spamspamspam'
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
# Ans : eggs can be Assigned with any other value and as 100 is an integer and integer could not be assigned with any other values hence 100 is invalid
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# Ans: int() for integer
#      float() for floating point number
#      str() for string version
#
#
#
#
#
# 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten ' + 99 + ' burritos.'
# Ans: we cannot concatenate str with str not with "int"
# we can correct it by converting "99" into a string using a string function [str()]
#
# code: 'I have eaten ' + str(99) + ' burritos.'

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str
